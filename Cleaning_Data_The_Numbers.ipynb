# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
Movie_Finance = pd.read_csv(r'C:\Users\rafav\Documents\Flatiron\Final Project_Section 1\project_data\tn_movie_budgets.csv')

# %%
Movie_Finance.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
Movie_Finance.shape
# Out:
# (5782, 6)

# %%
Movie_Finance.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
Movie_Finance.production_budget.str.replace('$', "").str.replace(',', '')
# Out:
# 0       425000000
# 1       410600000
# 2       350000000
# 3       330600000
# 4       317000000
#           ...
# 5777         7000
# 5778         6000
# 5779         5000
# 5780         1400
# 5781         1100
# Name: production_budget, Length: 5782, dtype: object

# %%
Movie_Finance.to_csv(r'C:\Users\rafav\Documents\Flatiron\Final Project_Section 1\Cleaned data\Module_1\Movie_Finance.csv')

# %%
Movie_Budgets = pd.read_csv(r'C:\Users\rafav\Documents\Flatiron\Final Project_Section 1\Cleaned data\Module_1\Movie_Finance.csv')

# %%
Movie_Budgets.head()
# Out:
#    Unnamed: 0  id release_date                                        movie  \
# 0           0   1    18-Dec-09                                       Avatar
# 1           1   2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2           2   3     7-Jun-19                                 Dark Phoenix
# 3           3   4     1-May-15                      Avengers: Age of Ultron
# 4           4   5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
fig, axes = plt.subplots(1, 2)

Movie_Budgets.hist('production_budget', bins=100, ax=axes[0])
Movie_Budgets.boxplot(column = ['production_budget'])

# %%
fig, axes = plt.subplots(1, 2)
Movie_Budgets.hist('domestic_gross', bins=100, ax=axes[0])
Movie_Budgets.boxplot(column = ['domestic_gross'])

# %%
fig, axes = plt.subplots(1, 2)
Movie_Budgets.hist('worldwide_gross', bins=100, ax=axes[0])
Movie_Budgets.boxplot(column = ['worldwide_gross'])

# %%
Movie_Budgets.isnull().sum()
# Out:
# Unnamed: 0           0
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
Movie_Budgets['ROI'] = Movie_Budgets['domestic_gross'] + Movie_Budgets['worldwide_gross'] - Movie_Budgets['production_budget']

# %%
Movie_Budgets.head()
# Out:
#    Unnamed: 0  id release_date                                        movie  \
# 0           0   1    18-Dec-09                                       Avatar
# 1           1   2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2           2   3     7-Jun-19                                 Dark Phoenix
# 3           3   4     1-May-15                      Avengers: Age of Ultron
# 4           4   5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross         ROI
# 0          425000000       760507625       2776345279  3111852904
# 1          410600000       241063875       1045663875   876127750
# 2          350000000        42762350        149762350  -157475300
# 3          330600000       459005868       1403013963  1531419831
# 4          317000000       620181382       1316721747  1619903129

# %%
Movie_Budgets['Domestic ROI'] = Movie_Budgets['domestic_gross'] - Movie_Budgets['production_budget']

# %%
Movie_Budgets.head()
# Out:
#    Unnamed: 0  id release_date                                        movie  \
# 0           0   1    18-Dec-09                                       Avatar
# 1           1   2    20-May-11  Pirates of the Caribbean: On Stranger Tides
# 2           2   3     7-Jun-19                                 Dark Phoenix
# 3           3   4     1-May-15                      Avengers: Age of Ultron
# 4           4   5    15-Dec-17            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross         ROI  \
# 0          425000000       760507625       2776345279  3111852904
# 1          410600000       241063875       1045663875   876127750
# 2          350000000        42762350        149762350  -157475300
# 3          330600000       459005868       1403013963  1531419831
# 4          317000000       620181382       1316721747  1619903129
#
#    Domestic ROI
# 0     335507625
# 1    -169536125
# 2    -307237650
# 3     128405868
# 4     303181382

# %%
sns.pairplot(Movie_Budgets)

# %%
Movie_Budgets.dtypes
# Out:
# Unnamed: 0            int64
# id                    int64
# release_date         object
# movie                object
# production_budget     int64
# domestic_gross        int64
# worldwide_gross       int64
# ROI                   int64
# Domestic ROI          int64
# dtype: object

# %%
Movie_Budgets.drop('Unnamed: 0', axis =1, inplace =True)

# %%
Movie_Budgets.head()
# Out:
#    id  production_budget  domestic_gross  worldwide_gross         ROI  \
# 0   1          425000000       760507625       2776345279  3111852904
# 1   2          410600000       241063875       1045663875   876127750
# 2   3          350000000        42762350        149762350  -157475300
# 3   4          330600000       459005868       1403013963  1531419831
# 4   5          317000000       620181382       1316721747  1619903129
#
#    Domestic ROI
# 0     335507625
# 1    -169536125
# 2    -307237650
# 3     128405868
# 4     303181382

# %%
Movie_Budgets.corr()
# Out:
#                          id  production_budget  domestic_gross  \
# id                 1.000000          -0.035278        0.008255
# production_budget -0.035278           1.000000        0.685682
# domestic_gross     0.008255           0.685682        1.000000
# worldwide_gross   -0.009422           0.748306        0.938853
# ROI                0.001859           0.643580        0.965476
# Domestic ROI       0.040832           0.099742        0.792663
#
#                    worldwide_gross       ROI  Domestic ROI
# id                       -0.009422  0.001859      0.040832
# production_budget         0.748306  0.643580      0.099742
# domestic_gross            0.938853  0.965476      0.792663
# worldwide_gross           1.000000  0.983933      0.656626
# ROI                       0.983933  1.000000      0.780732
# Domestic ROI              0.656626  0.780732      1.000000

# %%
sns.set_style('whitegrid') 
sns.lmplot(x ='production_budget', y ='ROI',data =Movie_Budgets,scatter_kws={'color': 'orange'})

# %%
sns.set_style('whitegrid') 
sns.lmplot(x ='production_budget', y ='domestic_gross', data =Movie_Budgets,scatter_kws={'color': 'grey'})

# %%
sns.set_style('whitegrid') 
sns.lmplot(x ='production_budget', y ='worldwide_gross', data =Movie_Budgets,line_kws={'color': 'blue'})
